# %% [markdown]
# ## Final Notebook
#
# # Introduction
#
# # Metric 1
# Our group decided to gather data from three data sets and determine the best neighborhood to live in in order to Survive a Zombie Apocolypse. We used Trees, its coverage,in my opinion allows us to shelter from zombies easier and keep us more hidden.
#
# # Metric 2
#
# Alex did Income per neighborhood. When you have more income, you have more of an ability to have better supplies, better armor, weaponry and a better ability to build a better fortress.
#
# # Metric 3
#
# Elizabeth did population per neighborhood. If a zombie apocolypse were to occur, it would be vital to have less of a population. You can trust no one, where there are more people there can be more infections therefore, whereverer the population is the least, that is the best chance of survival.

# %% [markdown]
# ## Metric #1- Patrick Smelt

# %%
#First Input Pandas to allow us to make some data visualizations
import pandas as pd
import geopandas
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Determining the Best Neighborhood to live in Pittsburgh to survive a zombie apocolypse.
#Starting off by creating Dictionary

treesFile = pd.read_csv("trees-pitt.csv")

trees_in_neighborhood = dict()

#caluate frequency of trees in each neighborhood and see how they provide the best coverage.
for index, row in treesFile.iterrows():
    trees = row['height']
    
    #assigning trees to the row of height
    
    if trees > 0:
        #telling the code that if the heigh is above 0 it can be classified as a tree.
        #the more trees their are, the more coverage you have which makes it harder for zombies.
        neighborhood = row['neighborhood']
        #variable assinged to neighborhood for its row
        if (neighborhood not in trees_in_neighborhood):
            trees_in_neighborhood[neighborhood] = 1
        else:
            trees_in_neighborhood[neighborhood] += 1
            
            #telling the dictionary to add up the number of trees in each neighborhood.

            
print(trees_in_neighborhood)
# Out:
# <ipython-input-2-5826cba55fb0>:4: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   treesFile = pd.read_csv("trees-pitt.csv")
# ...

# %% [markdown]
# # Now inputing the library that I will use for the Tree Data Set

# %%
#Now import the library the I will be using for the data set
treesFile = pd.read_csv("trees-pitt.csv")
treesFile
# Out:
# <ipython-input-3-d87499d47249>:2: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   treesFile = pd.read_csv("trees-pitt.csv")
#                id  address_number         street         common_name  \
# 0       754166088          7428.0  MONTICELLO ST               Stump
# 1      1946899269           220.0     BALVER AVE  Linden: Littleleaf
# 2      1431517397          2822.0      SIDNEY ST          Maple: Red
# 3       994063598           608.0     SUISMON ST      Maple: Freeman
# 4      1591838573          1135.0   N NEGLEY AVE       Maple: Norway
# ...           ...             ...            ...                 ...
# 45704    39047675  499 N LANG AVE     N LANG AVE       Maple: Norway
# 45705  1827907131             NaN            NaN        Maple: Sugar
# 45706  1513723611             NaN            NaN        Maple: Sugar
# 45707  1830872418             NaN            NaN        Maple: Sugar
# ...

# %% [markdown]
# # Now inputing the data that I will use for the nieghborhood dataset.

# %%
#Now showing the dataset for each of the neighborhoods in Pittsburgh
neighborhoods = pd.read_csv("neighborhoods.csv", sep=",")
neighborhoods
# Out:
#     objectid  fid_blockg statefp10 countyfp10 tractce10 blkgrpce10  \
# 0       1293         201        42        003    980600          1
# 1       1294          10        42        003    261200          1
# 2       1295          11        42        003    260900          1
# 3       1296           7        42        003    262000          1
# 4       1297           8        42        003    261500          1
# ..       ...         ...       ...        ...       ...        ...
# 85      1378         251        42        003    320400          3
# 86      1379         265        42        003    563000          4
# 87      1380         358        42        003    562500          1
# 88      1381         298        42        003    563100          3
# 89      1382          32        42        003    562600          1
#
#          geoid10     namelsad10 mtfcc10 funcstat10  ...    shape_ar_1  \
# 0   420039806001  Block Group 1   G5030          S  ...  1.068826e+07
# ...

# %% [markdown]
# Having a dictionary, with each dictionary with each tree in it, lets create a dataframe out of it and print 10 neighborhoods with a number of trees

# %%
treesFile = pd.DataFrame(list(trees_in_neighborhood.items()),columns = ['neighborhoods', 'trees'])
treesFile.sort_values(by = 'trees', ascending = False)
# Out:
#           neighborhoods  trees
# 25  Squirrel Hill South   2396
# 41  Squirrel Hill North   1586
# 0      South Side Flats   1452
# 16            Shadyside   1302
# 13         East Liberty   1211
# ..                  ...    ...
# 88                  NaN      3
# 89           Glen Hazel      2
# 82               Esplen      2
# 84          South Shore      1
# 90                 Hays      1
#
# [91 rows x 2 columns]

# %% [markdown]
# now to graph the merged data, lets use the first 15 highest neighborhoods with trees

# %%
neighborhoods = pd.read_csv("neighborhoods.csv")
treesFile.sort_values(by = ['trees'], ascending = False).head(15).plot.bar(x = 'neighborhoods', y = 'trees')

# %% [markdown]
#  Using the Data set of Neighborhoods in Pittsburgh, I will now create a map of Pittsburgh and its neighborhoods.

# %%
#now creating an empty map of Pittsburgh
import pandas as pd
import geopandas as gd
hood_map = gd.read_file("Neighborhoods_.shp")

#Here is a bar map for an empty map in Pittsburgh

hood = hood_map.plot()
hood

# %% [markdown]
# Now I merging my neighborhood data with my tree data

# %%
tree_map = hood_map.merge(treesFile, how = 'left', left_on = 'hood', right_on = 'neighborhoods')
tree_map = tree_map.fillna(0)
hood_map
# Out:
#     objectid  fid_blockg statefp10 countyfp10 tractce10 blkgrpce10  \
# 0          1         0.0        42        003    040500          1
# 1          2         1.0        42        003    040400          1
# 2          3         2.0        42        003    040200          2
# 3          4         3.0        42        003    030500          2
# 4          5         5.0        42        003    020300          1
# ..       ...         ...       ...        ...       ...        ...
# 85        88       298.0        42        003    563100          3
# 86        89        32.0        42        003    562600          1
# 87        90        57.0        42        003    250700          1
# 88        91        96.0        42        003    562300          2
# 89      1292         NaN      None       None      None       None
#
#          geoid10     namelsad10 mtfcc10 funcstat10  ...    shape_ar_1  \
# 0   420030405001  Block Group 1   G5030          S  ...  7.843108e+06
# ...

# %% [markdown]
# I created a map! With my data now merged, I was able to create this super cool map below! -  Shoutout Arjun.

# %%
tree_map.plot(column = 'trees', legend = True, legend_kwds = {'label' : 'trees'}, figsize = (10, 5))

# %% [markdown]
# ## Conclusion
#
# Whats up guys, So this is my data for trees, I was able to figure out most of the trees were in Squirrel Hill South.
#
# Therefore I believe that Squirrel Hill South would be the best place to live since it would guarentee me the most protection.

# %% [markdown]
# ## Metric #2 -- Alex

# %%
import pandas as pd
import geopandas
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Here I am loading in the neighborhood data

# %%
# load in neighborhood data
preincomes = pd.read_csv("Agg_income.csv", sep=",")
preincomes
# Out:
#            Neighborhood  Id     agg_inc  margin_error
# 0      Allegheny Center   1  39947000.0  6.437773e+06
# 1        Allegheny West   2  23793300.0  2.202594e+07
# 2             Allentown   3  38303700.0  7.490207e+06
# 3             Arlington   4  35349900.0  6.140663e+06
# 4     Arlington Heights   5   2389600.0  1.162393e+06
# ..                  ...  ..         ...           ...
# 86  Upper Lawrenceville  87  65738500.0  1.600713e+07
# 87             West End  88   3615800.0  2.204875e+06
# 88         West Oakland  89  16339500.0  3.412753e+06
# 89             Westwood  90  91857100.0  1.130450e+07
# 90              Windgap  91  34609300.0  6.432817e+06
#
# [91 rows x 4 columns]

# %% [markdown]
# Now to merge the neighborhoods with the aggregate incomes

# %%
incomes = preincomes[["Neighborhood", "agg_inc"]]
incomes
# Out:
#            Neighborhood     agg_inc
# 0      Allegheny Center  39947000.0
# 1        Allegheny West  23793300.0
# 2             Allentown  38303700.0
# 3             Arlington  35349900.0
# 4     Arlington Heights   2389600.0
# ..                  ...         ...
# 86  Upper Lawrenceville  65738500.0
# 87             West End   3615800.0
# 88         West Oakland  16339500.0
# 89             Westwood  91857100.0
# 90              Windgap  34609300.0
#
# [91 rows x 2 columns]

# %%
# read in the neighborhoods shape file
hoodmap = geopandas.read_file("Neighborhoods_.shp")
hoodmap.plot()

# %% [markdown]
# Above it an empty map of all the neighborhoods in Pittsburgh

# %%
#Figured out why bar plot wasnt working because string types needed to be int
print(incomes.dtypes)
# Out:
# Neighborhood     object
# agg_inc         float64
# dtype: object

# %% [markdown]
# Had some trouble to determine why the bar plot wasnt working and it was because the bar graph could not read the string types

# %%
#search how to convert series columns from string to float
incomes = incomes.astype({'agg_inc': float})
print(incomes.dtypes)
# Out:
# Neighborhood     object
# agg_inc         float64
# dtype: object

# %% [markdown]
# Now I am making a bar graph based on the merge values

# %%
incomes = incomes.sort_values('agg_inc', ascending = False)
#incomes.head()
incomes.head(20).plot.barh(x = "Neighborhood")

# %%
incMap = hoodmap.merge(incomes, how = 'left', left_on='hood', right_on='Neighborhood')
incMap
# Out:
#     objectid  fid_blockg statefp10 countyfp10 tractce10 blkgrpce10  \
# 0          1         0.0        42        003    040500          1
# 1          2         1.0        42        003    040400          1
# 2          3         2.0        42        003    040200          2
# 3          4         3.0        42        003    030500          2
# 4          5         5.0        42        003    020300          1
# ..       ...         ...       ...        ...       ...        ...
# 85        88       298.0        42        003    563100          3
# 86        89        32.0        42        003    562600          1
# 87        90        57.0        42        003    250700          1
# 88        91        96.0        42        003    562300          2
# 89      1292         NaN      None       None      None       None
#
#          geoid10     namelsad10 mtfcc10 funcstat10  ...  \
# 0   420030405001  Block Group 1   G5030          S  ...
# ...

# %% [markdown]
# Now plotting the merged map

# %%
incMap.plot(column = 'agg_inc')

# %%
incMap.plot(column='agg_inc', #set data used for coloring
            cmap='Reds',          #choose color pallete
            edgecolor='white', # outline districts in white
            legend = True,    #show the legend
            legend_kwds={'label': "Aggregate Neighborhood Incomes"}, #Label the legend
            figsize = (15,10),    #set the size
            missing_kwds={"color": "lightgrey"} #set districts with no data to gray
           )

# %% [markdown]
# # Conclusion
#
# Based on my data, we can tell that Squirrel Hill South has the highest Aggregate income,
# therefore squirrel hill south was have the best ability to surive a zombie apocolypse

# %% [markdown]
# ## Metric #3 -- Elizabeth

# %%
import pandas as pd 
import geopandas
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Now inputing data for my neighborhood dataset

# %%
hoods = pd.read_csv("neighborhoods.csv", sep=",")
hoods
# Out:
#     objectid  fid_blockg statefp10 countyfp10 tractce10 blkgrpce10  \
# 0       1293         201        42        003    980600          1
# 1       1294          10        42        003    261200          1
# 2       1295          11        42        003    260900          1
# 3       1296           7        42        003    262000          1
# 4       1297           8        42        003    261500          1
# ..       ...         ...       ...        ...       ...        ...
# 85      1378         251        42        003    320400          3
# 86      1379         265        42        003    563000          4
# 87      1380         358        42        003    562500          1
# 88      1381         298        42        003    563100          3
# 89      1382          32        42        003    562600          1
#
#          geoid10     namelsad10 mtfcc10 funcstat10  ...    shape_ar_1  \
# 0   420039806001  Block Group 1   G5030          S  ...  1.068826e+07
# ...

# %% [markdown]
# Here is an empty map of Pittsburgh

# %%
myhoods = geopandas.read_file("Neighborhoods_.shp")
myhoods.plot()

# %%
population = pd.read_csv("total-population.csv", sep=",")
population
# Out:
#            Neighborhood  Id  Estimate; Total  Margin of Error; Total
# 0      Allegheny Center   1           1411.0              196.000000
# 1        Allegheny West   2            343.0               96.000000
# 2             Allentown   3           2558.0              449.773276
# 3             Arlington   4           1852.0              348.188168
# 4     Arlington Heights   5            272.0              126.000000
# ..                  ...  ..              ...                     ...
# 86  Upper Lawrenceville  87           2754.0              435.708618
# 87             West End  88            235.0              138.000000
# 88         West Oakland  89           1717.0              285.001754
# 89             Westwood  90           3537.0              407.982843
# 90              Windgap  91           1534.0              367.828765
#
# [91 rows x 4 columns]

# %% [markdown]
# Above it my population dataset

# %% [markdown]
# Now I am merging my population dataset with my neighborhood dataset

# %%
mergepopulation = myhoods.merge(population, how='left', left_on='hood', right_on='Neighborhood')
mergepopulation
# Out:
#     objectid  fid_blockg statefp10 countyfp10 tractce10 blkgrpce10  \
# 0          1         0.0        42        003    040500          1
# 1          2         1.0        42        003    040400          1
# 2          3         2.0        42        003    040200          2
# 3          4         3.0        42        003    030500          2
# 4          5         5.0        42        003    020300          1
# ..       ...         ...       ...        ...       ...        ...
# 85        88       298.0        42        003    563100          3
# 86        89        32.0        42        003    562600          1
# 87        90        57.0        42        003    250700          1
# 88        91        96.0        42        003    562300          2
# 89      1292         NaN      None       None      None       None
#
#          geoid10     namelsad10 mtfcc10 funcstat10  ...  \
# 0   420030405001  Block Group 1   G5030          S  ...
# ...

# %% [markdown]
# Here is my merged map!!!

# %%
mergepopulation.dropna()
mergepopulation.plot(column='Estimate; Total', legend= True)

# %% [markdown]
# This now just shows my imported dataset and filtering the important information.

# %%
# import dataset 
people = pd.read_csv("total-population.csv")
# filter to important info
num_people = people.groupby("Neighborhood").sum()['Estimate; Total']
num_people.sort_values(ascending=False)
# Out:
# Neighborhood
# Squirrel Hill South    16042.0
# Shadyside              13562.0
# Brookline              13160.0
# Squirrel Hill North    11336.0
# Carrick                10122.0
#                         ...
# St. Clair                270.0
# West End                 235.0
# North Shore              205.0
# South Shore               12.0
# Chateau                    3.0
# Name: Estimate; Total, Length: 91, dtype: float64

# %% [markdown]
# Here is my bar graph that shows the estimate total for population.

# %%
people = people.sort_values('Estimate; Total', ascending=False)
people.tail(20).plot.barh(x='Neighborhood')

# %% [markdown]
# ## Conclusion
#
# So in my opinion the 'best' neighborhood is Chateau. It has the least population. It will survive the zombie attack. This is due to it having the least population which ensures the best option

# %% [markdown]
# ## Merged Metrics

# %%
df1 = treesFile.merge(population, how='left',left_on='neighborhoods',right_on='Neighborhood')
df2 = df1.merge(incomes, how='left',left_on="neighborhoods",right_on='Neighborhood')
df2
# Out:
#         neighborhoods  trees     Neighborhood_x    Id  Estimate; Total  \
# 0    South Side Flats   1452   South Side Flats  73.0           6292.0
# 1      East Allegheny    346     East Allegheny  26.0           2095.0
# 2       Highland Park   1080      Highland Park  40.0           6810.0
# 3            Sheraden    267           Sheraden  70.0           5684.0
# 4      Chartiers City     35     Chartiers City  21.0            560.0
# ..                ...    ...                ...   ...              ...
# 86         Mt. Oliver     13         Mt. Oliver  55.0            598.0
# 87  Northview Heights      6  Northview Heights  59.0           1545.0
# 88                NaN      3                NaN   NaN              NaN
# 89         Glen Hazel      2         Glen Hazel  36.0            716.0
# 90               Hays      1               Hays  38.0            405.0
#
#     Margin of Error; Total     Neighborhood_y      agg_inc
# ...

# %%
df2 = df2[['neighborhoods', 'trees','Estimate; Total', 'agg_inc']]
df2
# Out:
#         neighborhoods  trees  Estimate; Total      agg_inc
# 0    South Side Flats   1452           6292.0  233098400.0
# 1      East Allegheny    346           2095.0   56433100.0
# 2       Highland Park   1080           6810.0  242405400.0
# 3            Sheraden    267           5684.0  101081700.0
# 4      Chartiers City     35            560.0   13805200.0
# ..                ...    ...              ...          ...
# 86         Mt. Oliver     13            598.0   13962700.0
# 87  Northview Heights      6           1545.0    8755000.0
# 88                NaN      3              NaN          NaN
# 89         Glen Hazel      2            716.0    4773300.0
# 90               Hays      1            405.0    6432200.0
#
# [91 rows x 4 columns]

# %%
import pandas as pd
df3 = df2.copy()
df3['IPP'] = df3['agg_inc'].div(df3['Estimate; Total'].values)
#df3['TPP'] = df3['trees'].div(df3['Estimate; Total'].values)
df3
# Out:
#         neighborhoods  trees  Estimate; Total      agg_inc           TPP  \
# 0    South Side Flats   1452           6292.0  233098400.0  37046.789574
# 1      East Allegheny    346           2095.0   56433100.0  26937.040573
# 2       Highland Park   1080           6810.0  242405400.0  35595.506608
# 3            Sheraden    267           5684.0  101081700.0  17783.550317
# 4      Chartiers City     35            560.0   13805200.0  24652.142857
# ..                ...    ...              ...          ...           ...
# 86         Mt. Oliver     13            598.0   13962700.0  23348.996656
# 87  Northview Heights      6           1545.0    8755000.0   5666.666667
# 88                NaN      3              NaN          NaN           NaN
# 89         Glen Hazel      2            716.0    4773300.0   6666.620112
# 90               Hays      1            405.0    6432200.0  15881.975309
#
#              IPP
# 0   37046.789574
# 1   26937.040573
# 2   35595.506608
# 3   17783.550317
# ...

# %%
df3 = df3[['neighborhoods','trees','Estimate; Total','IPP']]
df3=df3.sort_values(by='IPP',ascending=False)

df3.plot(kind='bar',stacked=True)

# %%
df3.head(10).plot(kind='bar',stacked=True,x = 'neighborhoods')
df3
# Out:
#                 neighborhoods  trees  Estimate; Total            IPP
# 65             Strip District    428            747.0  122808.969210
# 54             Allegheny West    233            343.0   69368.221574
# 28                North Shore    428            205.0   60473.170732
# 42               Point Breeze    953           5414.0   58174.824529
# 37  Central Business District    953           4060.0   51837.438424
# ..                        ...    ...              ...            ...
# 87          Northview Heights      6           1545.0    5666.666667
# 38                      Bluff    200           6294.0    1748.522402
# 55                    Chateau    257              3.0            NaN
# 84                South Shore      1             12.0            NaN
# 88                        NaN      3              NaN            NaN
#
# [91 rows x 4 columns]

# %% [markdown]
# ## Conclusion
#
# Patrick Smelt - I learned that trees were most prevelant in Squirrel Hill South but when we accumulated the data into Income per person we found that the strip district ended up being the best.
#
# Elizabeth Iye - For my data set Chataeu had the least population. When we put all of the datas together we found out that Strip District is te best.
#
# Alex Caristan - Initially, I found that in total, Squirrel Hill South had the highest Aggregate income out of any of the neighborhoods. When merging the data and reviewing the stacked bar chart, it was evident that income was not the most accurate metric to be using so I decided to do income per person for each neighborhood and that completely changed the best neighborhood. In the end, changing to average income per person lead to the strip district being the best neighborhood to survive a zombie apocolypse in relation to the lowest population and hisghest number of trees.
